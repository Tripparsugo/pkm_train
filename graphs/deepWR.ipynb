# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./data/deepWR.csv")
df
# Out:
#           wr  deepLv        vs
# 0   0.062249       0  standard
# 1   0.457831       0    random
# 2   0.395582       2  standard
# 3   0.895792       2    random
# 4   0.413655       4  standard
# ..       ...     ...       ...
# 87  0.905622      86    random
# 88  0.478958      88  standard
# 89  0.925553      88    random
# 90  0.451807      90  standard
# 91  0.925253      90    random
#
# [92 rows x 3 columns]

# %%
ax = sns.lineplot(data=df, x="deepLv", y="wr", hue="vs")
ax.axhline(0.5, linestyle=":", color="red")
plt.show()
